# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import KFold, cross_val_score, StratifiedKFold, train_test_split
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from xgboost import XGBClassifier, XGBRegressor
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from sklearn.metrics import log_loss
from sklearn.naive_bayes import GaussianNB  
import matplotlib.pyplot as plt

# %%
cancer = pd.read_csv("/home/darkstar/Downloads/Cases/Wisconsin/BreastCancer.csv")
cancer
# Out:
#          Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0       61634      5             4              3        1       2      2
# 1       63375      9             1              2        6       4     10
# 2       76389     10             4              7        2       2      8
# 3       95719      6            10             10       10       8     10
# 4      128059      1             1              1        1       2      5
# ..        ...    ...           ...            ...      ...     ...    ...
# 694   1369821     10            10             10       10       5     10
# 695   1371026      5            10             10       10       4     10
# 696   1371920      5             1              1        1       2      1
# 697   8233704      4             1              1        1       1      1
# 698  13454352      1             1              3        1       2      1
#
#      BChromatin  NoemN  Mitoses      Class
# ...

# %%
cancer_dumm = pd.get_dummies(cancer, drop_first=True, dtype=int)
cancer_dumm
X = cancer_dumm.drop(['Code','Class_Malignant'], axis = 1)
y = cancer_dumm['Class_Malignant']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=23)

# %%
lr = LogisticRegression()
gbm = XGBClassifier(random_state=23)
svm = SVC(probability = True, random_state=23)
dtc = DecisionTreeClassifier(random_state=23)
models = [('LR', lr), ('SVM', svm),('TREE',dtc)]
stack = StackingClassifier(estimators=models, final_estimator=gbm)

stack.fit(X_train, y_train)
# Out:
# StackingClassifier(estimators=[('LR', LogisticRegression()),
#                                ('SVM', SVC(probability=True, random_state=23)),
#                                ('TREE',
#                                 DecisionTreeClassifier(random_state=23))],
#                    final_estimator=XGBClassifier(base_score=None, booster=None,
#                                                  callbacks=None,
#                                                  colsample_bylevel=None,
#                                                  colsample_bynode=None,
#                                                  colsample_bytree=None,
#                                                  early_stopping_rounds=None,
#                                                  enable_categorical=False,
#                                                  ev...
#                                                  gpu_id=None, grow_policy=None,
# ...

# %%
y_pred = stack.predict(X_test)
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob[:,1]))
# Out:
# 0.1526592575619045

# %% [markdown]
# ## Bankruptcy Dataset

# %%
bank = pd.read_csv("/home/darkstar/Documents/pg-dbda/module5_R-Programming/practice/day1/Datasets/Bankruptcy.csv")
bank
# Out:
#       NO  D  YR    R1    R2    R3    R4    R5    R6    R7  ...   R15   R16  \
# 0      1  0  78  0.23  0.08  0.02  0.03  0.46  0.12  0.19  ...  0.05  0.57
# 1      2  0  77  0.19  0.07  0.09  0.12  0.02  0.02  0.03  ...  0.09  0.12
# 2      3  0  72  0.07  0.02  0.03  0.05  0.06  0.10  0.14  ... -0.03  0.02
# 3      4  0  80  0.07  0.03  0.04  0.04  0.04  0.06  0.06  ... -0.02  0.01
# 4      5  0  81  0.09  0.02  0.03  0.04  0.06  0.08  0.11  ...  0.02  0.07
# ..   ... ..  ..   ...   ...   ...   ...   ...   ...   ...  ...   ...   ...
# 127  128  1  77  0.27  0.03  0.07  0.10  0.09  0.18  0.26  ...  0.11  0.06
# 128  129  1  77  0.32  0.03  0.03  0.09  0.05  0.06  0.16  ...  0.17  0.07
# 129  130  1  78  0.08  0.01  0.02  0.05  0.04  0.07  0.15  ...  0.19  0.07
# 130  131  1  78  0.14  0.01  0.05  0.07  0.02  0.09  0.14  ...  0.07  0.02
# 131  132  1  78  0.26  0.07  0.12  0.17  0.00  0.01  0.01  ...  0.05  0.04
#
#       R17   R18     R19   R20   R21   R22   R23   R24
# ...

# %%
X = bank.drop(['NO','D','YR'], axis = 1)
y = bank['D']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.3, random_state=23)

# %% [markdown]
# ## XGBoost as final estimator without passthrough while stacking

# %%
lr = LogisticRegression()
gbm = XGBClassifier(random_state=23)
svm_l = SVC(kernel='linear', probability = True, random_state=23)
svm_r = SVC(kernel='rbf', probability = True, random_state=23)
dtc = DecisionTreeClassifier(random_state=23)
gb = GaussianNB()
models = [('LR', lr), ('SVM_L', svm_l),('TREE',dtc),('SVM_R',svm_r)]
stack = StackingClassifier(estimators=models, final_estimator=gbm)

stack.fit(X_train, y_train)
# Out:
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_pred = stack.predict(X_test)
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob[:,1]))
# Out:
# 0.9146328687408148

# %% [markdown]
# ## XGBoost as final estimator with passthrough while stacking

# %%
lr = LogisticRegression()
gbm = XGBClassifier(random_state=23)
svm_l = SVC(kernel='linear', probability = True, random_state=23)
svm_r = SVC(kernel='rbf', probability = True, random_state=23)
dtc = DecisionTreeClassifier(random_state=23)
gb = GaussianNB()
models = [('LR', lr), ('SVM_L', svm_l),('TREE',dtc),('SVM_R',svm_r)]
stack = StackingClassifier(estimators=models, final_estimator=gbm, passthrough=True)

stack.fit(X_train, y_train)

y_pred = stack.predict(X_test)
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob[:,1]))
# Out:
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## random forest as final estimator without passthrough with stacking

# %%
lr = LogisticRegression()
rf = RandomForestClassifier(random_state=23)
svm_l = SVC(kernel='linear', probability = True, random_state=23)
svm_r = SVC(kernel='rbf', probability = True, random_state=23)
dtc = DecisionTreeClassifier(random_state=23)
gb = GaussianNB()
models = [('LR', lr), ('SVM_L', svm_l),('TREE',dtc),('SVM_R',svm_r)]
stack = StackingClassifier(estimators=models, final_estimator=rf)

stack.fit(X_train, y_train)
# Out:
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
y_pred = stack.predict(X_test)
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob[:,1]))
# Out:
# 0.6081972320943875

# %% [markdown]
# ## random forest as final estimator with passthrough with stacking

# %%
lr = LogisticRegression()
rf = RandomForestClassifier(random_state=23)
svm_l = SVC(kernel='linear', probability = True, random_state=23)
svm_r = SVC(kernel='rbf', probability = True, random_state=23)
dtc = DecisionTreeClassifier(random_state=23)
gb = GaussianNB()
models = [('LR', lr), ('SVM_L', svm_l),('TREE',dtc),('SVM_R',svm_r)]
stack = StackingClassifier(estimators=models, final_estimator=rf, passthrough=True)

stack.fit(X_train, y_train)

y_pred = stack.predict(X_test)
y_pred_prob = stack.predict_proba(X_test)
print(log_loss(y_test, y_pred_prob[:,1]))
# Out:
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /home/darkstar/lang/python/venv/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...
